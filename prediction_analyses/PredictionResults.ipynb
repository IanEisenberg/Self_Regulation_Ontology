# %% [markdown]
# This notebook provides a summary of the predictive analyses using task or survey data to predict demographic/health measures.

# %%
import os,glob,sys
import pickle
import numpy,pandas
pandas.options.display.max_colwidth = 0
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display, HTML
import seaborn as sns
import scipy.stats
from statsmodels.sandbox.stats.multicomp import multipletests
# %load_ext rpy2.ipython
from scipy.cluster.hierarchy import dendrogram,ward,cut_tree,leaves_list
from scipy.spatial.distance import pdist
from sklearn.preprocessing import StandardScaler

import selfregulation.prediction.behavpredict_V1 as behavpredict

clf='lasso'
acc,features=pickle.load(open('singularity_analyses/wrangler/%s_data_collapsed.pkl'%clf,'rb'))
cont_measure='r2' # use r^2 or MAE for non-binary variables
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# Check all variables to make sure they have the correct number of observations (1000 for baseline and baseline_shuffle, 100 for all others), and create tables summarizing data.

# %%
allvars={}
datasets=[]
for k in acc.keys():
    if len(acc[k])==0:
        print('no data for',k)
        continue
    datasets.append(k)
    for v in acc[k][cont_measure]['scores_cv']:
        allvars[v]=cont_measure
    for v in acc[k]['AUROC']['scores_cv']:
        allvars[v]='AUROC'

alldata={'r2':pandas.DataFrame(),'MAE':pandas.DataFrame(),'AUROC':pandas.DataFrame(),
        'r2_pval':pandas.DataFrame()}
#['baseline_shuffle','baseline','task','survey','discounting',
#          'stopping','intelligence',
#          'impulsivity','big5','risktaking','grit','emotion','bisbas',
#          'drift','nondecision','thresh']
target_n={}
goodcount={}
for d in datasets:
    if len(acc[k])==0:
        print('no data for',k)
        continue
    
    goodcount[d]={}
    if d.find('baseline')>-1:
        target_n[d]=1000
    else:
        target_n[d]=100
    examplefeature=list(features[d].keys())[0]
    print(d,features[d][examplefeature].shape[1])

    for v in acc[d]['r2']['scores_cv']:
        if not v in acc[d][allvars[v]]['scores_cv']:
            goodcount[d][v]=0
        else:
            goodcount[d][v]=numpy.isfinite(acc[d][allvars[v]]['scores_cv'][v]).sum()
        if goodcount[d][v]<target_n[d]:
            print(d,v,goodcount[d][v],features[d][v].shape[1])

for v in allvars:
    if allvars[v]==cont_measure:
        vars={}
        for k in datasets:
            if not 'r2' in acc[k]:
                continue
            vars[k]=acc[k]['r2']['scores_cv'].mean().T
        df=pandas.DataFrame(vars,index=[v])
        alldata['r2']=alldata['r2'].append(df)
        
        vars={}
        for k in datasets:
            if not 'MAE' in acc[k]:
                continue
            vars[k]=acc[k]['MAE']['scores_cv'].mean().T
        df=pandas.DataFrame(vars,index=[v])
        alldata['MAE']=alldata['MAE'].append(df)
    else:
        vars={}
        for k in datasets:
            if not 'AUROC' in acc[k]:
                continue
            vars[k]=acc[k]['AUROC']['scores_cv'].mean().T
        df=pandas.DataFrame(vars,index=[v])
        alldata['AUROC']=alldata['AUROC'].append(df)
# Out:
# no data for emotion
# intelligence 5
# stroop 6
# nondecision 15
# stopping 14
# stop_signal 8
# bisbas 6
# grit 3
# discounting 8
# threebytwo 6
# attention_network_task 8
# motor_selective_stop_signal 2
# discount_titrate 3
# thresh 15
# risktaking 21
# baseline_shuffle 2
# baseline_shuffle DivorceCount 999 2
# tower_of_london 6
# dot_pattern_expectancy 9
# baseline 2
# kirby 5
# big5 7
# task 107
# task HowOftenGuiltRemorseDrinking 33 107
# task AlcoholHowOften6Drinks 40 107
# task HowOftenFailedActivitiesDrinking 24 107
# impulsivity 13
# survey 67
# drift 27
# columbia_card_task_hot 7

# %% [markdown]
# Compute p values

# %%
target='baseline'
null='baseline_shuffle'
def get_pval(target,null,allvars,datasets,acc):
    data=[]
    vars=list(allvars.keys())
    vars.sort()
    for v in vars:
        #print(target,null,v)
        if not v in acc[target][allvars[v]]['scores_cv'] or not v in acc[null][allvars[v]]['scores_cv']:
            data.append([allvars[v],numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan])
            continue
        targdist=acc[target][allvars[v]]['scores_cv'][v].dropna()
        targmean=targdist.mean()
        nulldist=acc[null][allvars[v]]['scores_cv'][v].dropna()
        nullmean=nulldist.mean()
        targstd=targdist.std()
        pval=1-scipy.stats.percentileofscore(nulldist,targmean)/100.
        if targstd>0:
            #es=(targmean-nullmean)/targstd
            es=targmean-nullmean
        else:
            es=numpy.nan
        insample=acc[target][allvars[v]]['scores_insample'][v].mean()
        data.append([allvars[v],targmean,nullmean,es,insample,pval])
    df=pandas.DataFrame(data,index=vars,columns=['Measure','Target mean','Null Mean','Effect size','In-sample','p_unc'])
    return(df)
        
pvals={}
pvals[('baseline','baseline_shuffle')]=get_pval('baseline','baseline_shuffle',allvars,datasets,acc)
for d in datasets:
    if d.find('baseline')>-1 or len(acc[d])==0:
        continue
    print(d)
    pvals[(d,'baseline')]=get_pval(d,'baseline',allvars,datasets,acc)

pvals_fdr={}
for k in pvals:
    tmp=multipletests(pvals[k]['p_unc'])
    pvals[k]['p_fdr']=tmp[1]
# Out:
# intelligence
# stroop
# nondecision
# stopping
# stop_signal
# bisbas
# grit
# discounting
# threebytwo
# attention_network_task
# motor_selective_stop_signal
# discount_titrate
# thresh
# risktaking
# tower_of_london
# dot_pattern_expectancy
# kirby
# big5
# task
# impulsivity
# survey
# drift
# columbia_card_task_hot

# %%
def get_importances(v,dt,features,nfeats=3):
    if not v in features[dt]:
        print(v,'is not in features for',dt)
        return None
    
    #print(dt,'importances for:',v)
    imp=pandas.DataFrame({'importance':(features[dt][v].abs()>0).mean(0)})
    imp['mean']=features[dt][v].mean(0)
    imp=imp.sort_values(by='importance',ascending=False)
    
    if nfeats>(imp.shape[0]):
        nfeats=imp.shape[0]
    topfeats=imp.iloc[:nfeats]
    topfeats=topfeats.query('importance>0')
    return topfeats

def get_importance_list(sigp,dt,features):
    implist=[]
    for v in sigp.index:
        i=get_importances(v,dt,features)
        implist.append([list(i.index)])
    df=pandas.DataFrame({'top features':implist})
    df.index=sigp.index
    return df

# plot var for all datasets
def plotvars(v,pvals,datasets,allvars,plotcutoff=True,
            plotbaseline=False):

    df=[]
    errors=[]
    ds=[]
    for k in datasets:
        if not allvars[v] in acc[k]:
            continue
        if not v in acc[k][allvars[v]]['scores_cv']:
            continue
        targdist=acc[k][allvars[v]]['scores_cv'][v].dropna()
        df.append(targdist.mean())
        ds.append(k)
        errors.append(targdist.std())
    df=pandas.DataFrame({'mean':df},index=ds)
    errors=pandas.DataFrame({'mean':errors},index=ds)
    if allvars[v]=='AUROC':
        df.plot.bar(yerr=errors,legend=False,ylim=(0.45,numpy.max(df.values)*1.1))
    else:
        df.plot.bar(yerr=errors,legend=False)
    plt.title(v)
    plt.ylabel(allvars[v]+' +/- SE across CV runs')
    if plotcutoff:
        cutoff=acc['baseline'][allvars[v]]['scores_cv'][v].dropna().quantile(0.95)
        plt.plot([0,1000],[cutoff,cutoff],'k--',linewidth=0.5)
    if plotbaseline:
        baseline=acc['baseline'][allvars[v]]['scores_cv'][v].dropna().mean()
        plt.plot([0,1000],[baseline,baseline],'k--',linewidth=0.5)

# %% [markdown]
# ## List all variables showing activity greater for baseline model vs shuffled model

# %%
sigp={}
pthresh=0.05
k=('baseline','baseline_shuffle')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
for v in sigp[k].index:
    plotvars(v,pvals,datasets,allvars)
# Out:
#                                     Measure  Target mean  Null Mean  \
# Age                                  r2      1.000000     0.002725
# HeightInches                         r2      0.379233     0.002766
# LongestRelationship                  r2      0.267142     0.002867
# DivorceCount.binarized               AUROC   0.736961     0.499135
# ChildrenNumber.binarized             AUROC   0.695951     0.497903
# DivorceCount                         r2      0.177983     0.002890
# RelationshipNumber                   r2      0.154190     0.002797
# ChildrenNumber                       r2      0.127504     0.002880
# RetirementPercentStocks.binarized    AUROC   0.623150     0.501566
# RelationshipStatus.binarized         AUROC   0.620574     0.499214
# TrafficAccidentsLifeCount.binarized  AUROC   0.611683     0.498427
# RentOwn                              AUROC   0.608664     0.500105
# LifetimeSmoke100Cigs                 AUROC   0.601179     0.500640
# HowLongSmoked.binarized              AUROC   0.601337     0.501796
# RetirementAccount                    AUROC   0.587012     0.500626
# MortgageDebt.binarized               AUROC   0.584509     0.500114
# AlcoholHowOften6Drinks.binarized     AUROC   0.575705     0.499936
# HowLongSmoked                        r2      0.076529     0.002578
# MortgageDebt                         r2      0.054979     0.003077
# TrafficAccidentsLifeCount            r2      0.052681     0.002677
# WeightPounds                         r2      0.052129     0.002475
# ArrestedChargedLifeCount             r2      0.038000     0.002524
# Nervous                              r2      0.037322     0.002748
# RestlessFidgety                      r2      0.028336     0.002677
# EverythingIsEffort                   r2      0.021692     0.002737
# Sex                                  AUROC   1.000000     0.499675
#
#                                      Effect size  In-sample  p_unc  p_fdr  \
# Age                                  0.997275     1.000000   0.0    0.0
# HeightInches                         0.376466     0.387085   0.0    0.0
# LongestRelationship                  0.264276     0.274270   0.0    0.0
# DivorceCount.binarized               0.237826     0.549379   0.0    0.0
# ChildrenNumber.binarized             0.198048     0.646124   0.0    0.0
# DivorceCount                         0.175093     0.204752   0.0    0.0
# RelationshipNumber                   0.151393     0.162268   0.0    0.0
# ChildrenNumber                       0.124623     0.138086   0.0    0.0
# RetirementPercentStocks.binarized    0.121584     0.497496   0.0    0.0
# RelationshipStatus.binarized         0.121360     0.620904   0.0    0.0
# TrafficAccidentsLifeCount.binarized  0.113256     0.611670   0.0    0.0
# RentOwn                              0.108559     0.547897   0.0    0.0
# LifetimeSmoke100Cigs                 0.100539     0.605183   0.0    0.0
# HowLongSmoked.binarized              0.099541     0.605695   0.0    0.0
# RetirementAccount                    0.086386     0.496646   0.0    0.0
# MortgageDebt.binarized               0.084395     0.500309   0.0    0.0
# AlcoholHowOften6Drinks.binarized     0.075770     0.527936   0.0    0.0
# HowLongSmoked                        0.073951     0.085432   0.0    0.0
# MortgageDebt                         0.051901     0.066019   0.0    0.0
# TrafficAccidentsLifeCount            0.050004     0.063120   0.0    0.0
# WeightPounds                         0.049654     0.061668   0.0    0.0
# ArrestedChargedLifeCount             0.035476     0.048223   0.0    0.0
# Nervous                              0.034575     0.046399   0.0    0.0
# RestlessFidgety                      0.025659     0.037336   0.0    0.0
# EverythingIsEffort                   0.018955     0.033260   0.0    0.0
# Sex                                 NaN           1.000000   0.0    0.0
#
#                                      top features
# Age                                  [[Age]]
# HeightInches                         [[Sex, Age]]
# LongestRelationship                  [[Age, Sex]]
# DivorceCount.binarized               [[Age, Sex]]
# ChildrenNumber.binarized             [[Age, Sex]]
# DivorceCount                         [[Age, Sex]]
# RelationshipNumber                   [[Age, Sex]]
# ChildrenNumber                       [[Sex, Age]]
# RetirementPercentStocks.binarized    [[Age, Sex]]
# RelationshipStatus.binarized         [[Sex, Age]]
# TrafficAccidentsLifeCount.binarized  [[Age, Sex]]
# RentOwn                              [[Age, Sex]]
# LifetimeSmoke100Cigs                 [[Age, Sex]]
# HowLongSmoked.binarized              [[Age, Sex]]
# RetirementAccount                    [[Age, Sex]]
# MortgageDebt.binarized               [[Age, Sex]]
# AlcoholHowOften6Drinks.binarized     [[Sex, Age]]
# HowLongSmoked                        [[Age, Sex]]
# MortgageDebt                         [[Age, Sex]]
# TrafficAccidentsLifeCount            [[Age, Sex]]
# WeightPounds                         [[Sex, Age]]
# ArrestedChargedLifeCount             [[Sex, Age]]
# Nervous                              [[Age, Sex]]
# RestlessFidgety                      [[Age, Sex]]
# EverythingIsEffort                   [[Age, Sex]]
# Sex                                  [[Sex]]
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
get_importances('Obese','survey',features)
# Out:
#                                        importance      mean
# five_facet_mindfulness_survey.observe  1.0        -0.269396
# dospert_rp_survey.recreational         1.0         0.392616
# time_perspective_survey.past_negative  1.0        -0.354049

# %% [markdown]
# ## Example of overfitting

# %%
k=('survey','baseline')
plt.figure(figsize=(8,8))
r2data=pvals[k].query('Measure == "r2"')
plt.scatter(r2data['Target mean'],r2data['In-sample'])
plt.plot([0,1],[0,1])
plt.axis([0,0.5,0,0.5])
plt.xlabel('Out-of-sample R^2',fontsize=20)
plt.ylabel('In-sample R^2',fontsize=20)
plt.savefig('overfitting.png',dpi=300)

# %%
k=('survey','baseline')
plt.figure(figsize=(8,8))
r2data=pvals[k].query('Measure == "AUROC"')
plt.scatter(r2data['Target mean'],r2data['In-sample'])
plt.plot([0,1],[0,1])
plt.axis([0.4,0.8,0.4,.8])
plt.xlabel('Out-of-sample AUC',fontsize=20)
plt.ylabel('In-sample AUC',fontsize=20)
plt.savefig('overfitting_AUC.png',dpi=300)

# %% [markdown]
# ## Show variables with greater prediction for survey vs. baseline

# %%
k=('survey','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
#for v in sigp[k].index:
#    plotvars(v,pvals,datasets,allvars)
# Out:
#                                            Measure  Target mean  Null Mean  \
# EverythingIsEffort                          r2      0.311615     0.021692
# Worthless                                   r2      0.274290     0.009320
# Hopeless                                    r2      0.257543     0.013748
# Nervous                                     r2      0.271560     0.037322
# Depressed                                   r2      0.234864     0.006879
# DaysHalfLastMonth                           r2      0.219263     0.001559
# Hopeless.binarized                          AUROC   0.740134     0.540419
# AlcoholHowManyDrinksDay                     r2      0.189819     0.002484
# EverythingIsEffort.binarized                AUROC   0.737792     0.554889
# Worthless.binarized                         AUROC   0.735083     0.552286
# Depressed.binarized                         AUROC   0.730857     0.549231
# RestlessFidgety                             r2      0.201662     0.028336
# BMI                                         r2      0.169205     0.001352
# RestlessFidgety.binarized                   AUROC   0.681021     0.525154
# AlcoholHowOften                             r2      0.149591     0.001031
# DaysLostLastMonth                           r2      0.159708     0.012756
# WeightPounds                                r2      0.191241     0.052129
# AlcoholHowManyDrinksDay.binarized           AUROC   0.658928     0.524419
# AlcoholHowOften6Drinks.binarized            AUROC   0.700091     0.575705
# Nervous.binarized                           AUROC   0.707836     0.588234
# HowOftenFailedActivitiesDrinking.binarized  AUROC   0.591760     0.472534
# Obese                                       AUROC   0.668345     0.551033
# AlcoholHowOften.binarized                   AUROC   0.583525     0.468331
# HowOftenCantStopDrinking                    r2      0.104162     0.001051
# HowOftenCantStopDrinking.binarized          AUROC   0.635935     0.534708
# RelativeFriendConcernedDrinking             r2      0.101458     0.001810
# DaysPhysicalHealthFeelings.binarized        AUROC   0.650218     0.559158
# CannabisHoursStoned                         r2      0.088963     0.002483
# HowOftenUnableRememberDrinking.binarized    AUROC   0.618565     0.540953
# HowSoonSmokeAfterWaking.binarized           AUROC   0.626675     0.553871
# HowOftenGuiltRemorseDrinking.binarized      AUROC   0.615901     0.546239
# HowOftenUnableRememberDrinking              r2      0.070013     0.001016
# InjuredDrinking                             r2      0.070105     0.002719
# CigsPerDay.binarized                        AUROC   0.612933     0.548350
# SmokeEveryDay.binarized                     AUROC   0.613868     0.551976
# CannabisHowOften.binarized                  AUROC   0.592045     0.540297
# DaysPhysicalHealthFeelings                  r2      0.049391     0.001746
# HighestEducation                            r2      0.059486     0.013093
# RelationshipNumber                          r2      0.200395     0.154190
# RetirementAccount                           AUROC   0.629665     0.587012
# RetirementPercentStocks.binarized           AUROC   0.662502     0.623150
# HowLongSmoked.binarized                     AUROC   0.638921     0.601337
# CannabisHowOften                            r2      0.039917     0.002949
# CaffienatedSodaCansPerDay                   r2      0.038638     0.004000
# ArrestedChargedLifeCount.binarized          AUROC   0.602514     0.568971
# ChildrenNumber.binarized                    AUROC   0.728521     0.695951
# SmokeEveryDay                               r2      0.038422     0.006009
# MortgageDebt                                r2      0.086134     0.054979
# LifetimeSmoke100Cigs                        AUROC   0.632089     0.601179
# ArrestedChargedLifeCount                    r2      0.067175     0.038000
# HouseholdIncome                             r2      0.040478     0.012531
# HowLongSmoked                               r2      0.104243     0.076529
# HowSoonSmokeAfterWaking                     r2      0.024917     0.000906
# MortgageDebt.binarized                      AUROC   0.605003     0.584509
#
#                                             Effect size  In-sample  p_unc  \
# EverythingIsEffort                          0.289923     0.378363   0.000
# Worthless                                   0.264970     0.340033   0.000
# Hopeless                                    0.243795     0.333058   0.000
# Nervous                                     0.234237     0.332014   0.000
# Depressed                                   0.227986     0.316230   0.000
# DaysHalfLastMonth                           0.217704     0.306949   0.000
# Hopeless.binarized                          0.199716     0.767312   0.000
# AlcoholHowManyDrinksDay                     0.187335     0.220110   0.000
# EverythingIsEffort.binarized                0.182903     0.780408   0.000
# Worthless.binarized                         0.182798     0.770051   0.000
# Depressed.binarized                         0.181625     0.772944   0.000
# RestlessFidgety                             0.173326     0.285498   0.000
# BMI                                         0.167854     0.258822   0.000
# RestlessFidgety.binarized                   0.155867     0.734783   0.000
# AlcoholHowOften                             0.148560     0.210296   0.000
# DaysLostLastMonth                           0.146952     0.270865   0.000
# WeightPounds                                0.139112     0.289909   0.000
# AlcoholHowManyDrinksDay.binarized           0.134510     0.716594   0.000
# AlcoholHowOften6Drinks.binarized            0.124386     0.739531   0.000
# Nervous.binarized                           0.119603     0.769099   0.000
# HowOftenFailedActivitiesDrinking.binarized  0.119226     0.612292   0.000
# Obese                                       0.117312     0.717278   0.000
# AlcoholHowOften.binarized                   0.115194     0.651201   0.000
# HowOftenCantStopDrinking                    0.103110     0.182104   0.000
# HowOftenCantStopDrinking.binarized          0.101228     0.654225   0.000
# RelativeFriendConcernedDrinking             0.099649     0.177290   0.000
# DaysPhysicalHealthFeelings.binarized        0.091060     0.688659   0.000
# CannabisHoursStoned                         0.086481     0.238069   0.000
# HowOftenUnableRememberDrinking.binarized    0.077613     0.604102   0.000
# HowSoonSmokeAfterWaking.binarized           0.072803     0.653831   0.000
# HowOftenGuiltRemorseDrinking.binarized      0.069662     0.576717   0.000
# HowOftenUnableRememberDrinking              0.068996     0.108287   0.000
# InjuredDrinking                             0.067386     0.110055   0.000
# CigsPerDay.binarized                        0.064584     0.664109   0.000
# SmokeEveryDay.binarized                     0.061892     0.694521   0.000
# CannabisHowOften.binarized                  0.051748     0.641665   0.000
# DaysPhysicalHealthFeelings                  0.047645     0.151481   0.000
# HighestEducation                            0.046393     0.183103   0.000
# RelationshipNumber                          0.046205     0.292852   0.000
# RetirementAccount                           0.042653     0.695972   0.000
# RetirementPercentStocks.binarized           0.039352     0.717587   0.000
# HowLongSmoked.binarized                     0.037584     0.689080   0.000
# CannabisHowOften                            0.036967     0.171822   0.000
# CaffienatedSodaCansPerDay                   0.034638     0.108060   0.000
# ArrestedChargedLifeCount.binarized          0.033542     0.645511   0.000
# ChildrenNumber.binarized                    0.032570     0.745247   0.000
# SmokeEveryDay                               0.032413     0.112196   0.000
# MortgageDebt                                0.031156     0.152073   0.000
# LifetimeSmoke100Cigs                        0.030910     0.677338   0.000
# ArrestedChargedLifeCount                    0.029175     0.126482   0.000
# HouseholdIncome                             0.027947     0.112900   0.000
# HowLongSmoked                               0.027714     0.163973   0.000
# HowSoonSmokeAfterWaking                     0.024011     0.078998   0.000
# MortgageDebt.binarized                      0.020494     0.637479   0.001
#
#                                                p_fdr  \
# EverythingIsEffort                          0.000000
# Worthless                                   0.000000
# Hopeless                                    0.000000
# Nervous                                     0.000000
# Depressed                                   0.000000
# DaysHalfLastMonth                           0.000000
# Hopeless.binarized                          0.000000
# AlcoholHowManyDrinksDay                     0.000000
# EverythingIsEffort.binarized                0.000000
# Worthless.binarized                         0.000000
# Depressed.binarized                         0.000000
# RestlessFidgety                             0.000000
# BMI                                         0.000000
# RestlessFidgety.binarized                   0.000000
# AlcoholHowOften                             0.000000
# DaysLostLastMonth                           0.000000
# WeightPounds                                0.000000
# AlcoholHowManyDrinksDay.binarized           0.000000
# AlcoholHowOften6Drinks.binarized            0.000000
# Nervous.binarized                           0.000000
# HowOftenFailedActivitiesDrinking.binarized  0.000000
# Obese                                       0.000000
# AlcoholHowOften.binarized                   0.000000
# HowOftenCantStopDrinking                    0.000000
# HowOftenCantStopDrinking.binarized          0.000000
# RelativeFriendConcernedDrinking             0.000000
# DaysPhysicalHealthFeelings.binarized        0.000000
# CannabisHoursStoned                         0.000000
# HowOftenUnableRememberDrinking.binarized    0.000000
# HowSoonSmokeAfterWaking.binarized           0.000000
# HowOftenGuiltRemorseDrinking.binarized      0.000000
# HowOftenUnableRememberDrinking              0.000000
# InjuredDrinking                             0.000000
# CigsPerDay.binarized                        0.000000
# SmokeEveryDay.binarized                     0.000000
# CannabisHowOften.binarized                  0.000000
# DaysPhysicalHealthFeelings                  0.000000
# HighestEducation                            0.000000
# RelationshipNumber                          0.000000
# RetirementAccount                           0.000000
# RetirementPercentStocks.binarized           0.000000
# HowLongSmoked.binarized                     0.000000
# CannabisHowOften                            0.000000
# CaffienatedSodaCansPerDay                   0.000000
# ArrestedChargedLifeCount.binarized          0.000000
# ChildrenNumber.binarized                    0.000000
# SmokeEveryDay                               0.000000
# MortgageDebt                                0.000000
# LifetimeSmoke100Cigs                        0.000000
# ArrestedChargedLifeCount                    0.000000
# HouseholdIncome                             0.000000
# HowLongSmoked                               0.000000
# HowSoonSmokeAfterWaking                     0.000000
# MortgageDebt.binarized                      0.036342
#
#                                                                                                                                                                                             top features
# EverythingIsEffort                          [[mindful_attention_awareness_survey.mindfulness, ten_item_personality_survey.emotional_stability, upps_impulsivity_survey.lack_of_premeditation]]
# Worthless                                   [[five_facet_mindfulness_survey.nonjudge, time_perspective_survey.past_negative, ten_item_personality_survey.emotional_stability]]
# Hopeless                                    [[Age, future_time_perspective_survey.future_time_perspective, ten_item_personality_survey.emotional_stability]]
# Nervous                                     [[ten_item_personality_survey.emotional_stability, bis_bas_survey.BIS, time_perspective_survey.past_negative]]
# Depressed                                   [[ten_item_personality_survey.emotional_stability, time_perspective_survey.past_negative, selection_optimization_compensation_survey.optimization.ReflogTr]]
# DaysHalfLastMonth                           [[selection_optimization_compensation_survey.optimization.ReflogTr, bis_bas_survey.BIS, time_perspective_survey.past_negative]]
# Hopeless.binarized                          [[time_perspective_survey.past_negative, ten_item_personality_survey.emotional_stability, five_facet_mindfulness_survey.nonjudge]]
# AlcoholHowManyDrinksDay                     [[sensation_seeking_survey.disinhibition, dospert_rt_survey.health_safety, dospert_eb_survey.health_safety.logTr]]
# EverythingIsEffort.binarized                [[five_facet_mindfulness_survey.act_with_awareness, bis_bas_survey.BIS, time_perspective_survey.past_negative]]
# Worthless.binarized                         [[time_perspective_survey.past_negative, self_regulation_survey.control, five_facet_mindfulness_survey.nonjudge]]
# Depressed.binarized                         [[time_perspective_survey.past_negative, ten_item_personality_survey.emotional_stability, upps_impulsivity_survey.negative_urgency]]
# RestlessFidgety                             [[five_facet_mindfulness_survey.observe, five_facet_mindfulness_survey.act_with_awareness, time_perspective_survey.past_negative]]
# BMI                                         [[eating_survey.emotional_eating, leisure_time_activity_survey.activity_level, brief_self_control_survey.self_control]]
# RestlessFidgety.binarized                   [[five_facet_mindfulness_survey.observe, dospert_rp_survey.ethical, mindful_attention_awareness_survey.mindfulness]]
# AlcoholHowOften                             [[sensation_seeking_survey.disinhibition, time_perspective_survey.past_positive, dospert_rt_survey.financial]]
# DaysLostLastMonth                           [[upps_impulsivity_survey.positive_urgency, ten_item_personality_survey.emotional_stability, time_perspective_survey.past_negative]]
# WeightPounds                                [[Sex, leisure_time_activity_survey.activity_level, eating_survey.emotional_eating]]
# AlcoholHowManyDrinksDay.binarized           [[sensation_seeking_survey.disinhibition, dospert_eb_survey.health_safety.logTr, dospert_rt_survey.health_safety]]
# AlcoholHowOften6Drinks.binarized            [[sensation_seeking_survey.disinhibition, dospert_rt_survey.health_safety, erq_survey.reappraisal]]
# Nervous.binarized                           [[time_perspective_survey.past_negative, bis_bas_survey.BAS_fun_seeking, time_perspective_survey.future]]
# HowOftenFailedActivitiesDrinking.binarized  [[sensation_seeking_survey.boredom_susceptibility, dospert_rp_survey.social, eating_survey.cognitive_restraint]]
# Obese                                       [[five_facet_mindfulness_survey.observe, dospert_rp_survey.recreational, time_perspective_survey.past_negative]]
# AlcoholHowOften.binarized                   [[bis11_survey.Attentional, dospert_rt_survey.financial, time_perspective_survey.past_negative]]
# HowOftenCantStopDrinking                    [[sensation_seeking_survey.disinhibition, upps_impulsivity_survey.positive_urgency, dospert_rt_survey.health_safety]]
# HowOftenCantStopDrinking.binarized          [[bis11_survey.Attentional, dospert_rp_survey.health_safety, ten_item_personality_survey.extraversion]]
# RelativeFriendConcernedDrinking             [[dospert_rt_survey.health_safety, bis11_survey.Motor, sensation_seeking_survey.disinhibition]]
# DaysPhysicalHealthFeelings.binarized        [[five_facet_mindfulness_survey.observe, dospert_rt_survey.social, time_perspective_survey.past_positive]]
# CannabisHoursStoned                         [[bis11_survey.Motor, sensation_seeking_survey.disinhibition, time_perspective_survey.past_positive]]
# HowOftenUnableRememberDrinking.binarized    [[dospert_rt_survey.health_safety, sensation_seeking_survey.disinhibition, dospert_rp_survey.ethical]]
# HowSoonSmokeAfterWaking.binarized           [[time_perspective_survey.present_hedonistic, brief_self_control_survey.self_control, dospert_rt_survey.health_safety]]
# HowOftenGuiltRemorseDrinking.binarized      [[eating_survey.cognitive_restraint, selection_optimization_compensation_survey.loss_based_selection, dospert_rt_survey.health_safety]]
# HowOftenUnableRememberDrinking              [[sensation_seeking_survey.disinhibition, brief_self_control_survey.self_control, dospert_rt_survey.health_safety]]
# InjuredDrinking                             [[dospert_rt_survey.health_safety, brief_self_control_survey.self_control, bis11_survey.Motor]]
# CigsPerDay.binarized                        [[eating_survey.cognitive_restraint, dospert_rp_survey.health_safety, selection_optimization_compensation_survey.loss_based_selection]]
# SmokeEveryDay.binarized                     [[Sex, sensation_seeking_survey.disinhibition, Age]]
# CannabisHowOften.binarized                  [[eating_survey.uncontrolled_eating, dospert_eb_survey.financial, sensation_seeking_survey.disinhibition]]
# DaysPhysicalHealthFeelings                  [[leisure_time_activity_survey.activity_level, bis_bas_survey.BAS_drive, future_time_perspective_survey.future_time_perspective]]
# HighestEducation                            [[leisure_time_activity_survey.activity_level, bis11_survey.Nonplanning, dospert_eb_survey.social]]
# RelationshipNumber                          [[Age, dospert_rt_survey.social, sensation_seeking_survey.disinhibition]]
# RetirementAccount                           [[Sex, sensation_seeking_survey.experience_seeking, eating_survey.emotional_eating]]
# RetirementPercentStocks.binarized           [[dospert_rt_survey.social, dospert_rt_survey.financial, selection_optimization_compensation_survey.elective_selection]]
# HowLongSmoked.binarized                     [[Age, sensation_seeking_survey.disinhibition, dospert_rt_survey.health_safety]]
# CannabisHowOften                            [[dospert_rt_survey.social, bis11_survey.Motor, five_facet_mindfulness_survey.nonreact]]
# CaffienatedSodaCansPerDay                   [[eating_survey.cognitive_restraint, leisure_time_activity_survey.activity_level, eating_survey.emotional_eating]]
# ArrestedChargedLifeCount.binarized          [[ten_item_personality_survey.extraversion, dospert_eb_survey.ethical, dospert_rt_survey.health_safety]]
# ChildrenNumber.binarized                    [[five_facet_mindfulness_survey.observe, dospert_eb_survey.financial, Age]]
# SmokeEveryDay                               [[five_facet_mindfulness_survey.act_with_awareness, dospert_rt_survey.health_safety, ten_item_personality_survey.openness]]
# MortgageDebt                                [[Age, time_perspective_survey.past_positive, time_perspective_survey.past_negative]]
# LifetimeSmoke100Cigs                        [[Age, dospert_rt_survey.health_safety, sensation_seeking_survey.disinhibition]]
# ArrestedChargedLifeCount                    [[dospert_rt_survey.health_safety, Sex, dospert_rt_survey.recreational]]
# HouseholdIncome                             [[eating_survey.cognitive_restraint, time_perspective_survey.past_positive, time_perspective_survey.past_negative]]
# HowLongSmoked                               [[Age, dospert_eb_survey.social, sensation_seeking_survey.experience_seeking]]
# HowSoonSmokeAfterWaking                     [[sensation_seeking_survey.disinhibition, selection_optimization_compensation_survey.loss_based_selection, Sex]]
# MortgageDebt.binarized                      [[grit_scale_survey.grit, self_regulation_survey.control, Age]]
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ## Show variables with greater prediction for task vs. baseline

# %%
k=('task','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
#for v in sigp[k].index:
#    plotvars(v,pvals,datasets,allvars)
# Out:
#                         Measure  Target mean  Null Mean  Effect size  \
# HighestEducation         r2      0.114616     0.013093   0.101522
# HouseholdIncome          r2      0.071924     0.012531   0.059393
# CigsPerDay.binarized     AUROC   0.590894     0.548350   0.042544
# SmokeEveryDay.binarized  AUROC   0.586648     0.551976   0.034672
# Worthless                r2      0.031514     0.009320   0.022194
# BMI                      r2      0.013975     0.001352   0.012624
# Depressed                r2      0.017024     0.006879   0.010145
#
#                          In-sample  p_unc  p_fdr  \
# HighestEducation         0.174833   0.0    0.0
# HouseholdIncome          0.169149   0.0    0.0
# CigsPerDay.binarized     0.718088   0.0    0.0
# SmokeEveryDay.binarized  0.716365   0.0    0.0
# Worthless                0.099400   0.0    0.0
# BMI                      0.120456   0.0    0.0
# Depressed                0.069813   0.0    0.0
#
#                                                                                                                                                   top features
# HighestEducation         [[cognitive_reflection_survey.correct_proportion, bickel_titrator.hyp_discount_rate_medium.logTr, writing_task.positive_probability]]
# HouseholdIncome          [[cognitive_reflection_survey.correct_proportion, writing_task.positive_probability, writing_task.neutral_probability]]
# CigsPerDay.binarized     [[information_sampling_task.Fixed_Win_motivation, stop_signal.SSRT_low, information_sampling_task.Fixed_Win_P_correct]]
# SmokeEveryDay.binarized  [[information_sampling_task.Fixed_Win_motivation, simon.hddm_thresh, kirby.hyp_discount_rate_large.logTr]]
# Worthless                [[writing_task.positive_probability, threebytwo.hddm_thresh, Age]]
# BMI                      [[stim_selective_stop_signal.hddm_thresh.logTr, dietary_decision.health_sensitivity, stroop.hddm_drift]]
# Depressed                [[writing_task.positive_probability, threebytwo.hddm_thresh, choice_reaction_time.hddm_drift]]

# %% [markdown]
# ### Make figure for paper

# %%
figurevars=['BMI','AlcoholHowManyDrinksDay','SmokeEveryDay',
            'CannabisHowOften','DaysLostLastMonth']


def plot_paper_vars(vars,pvals,datasets,allvars):
    f, axarr = plt.subplots(2, 2,figsize=(18,16))
    xy=[[0,0],[0,1],[1,0],[1,1]]
    ctr=0
    for v in vars:
        df=[]
        errors=[]
        ds=[]
        for k in datasets:
            if not allvars[v] in acc[k]:
                continue
            if not v in acc[k][allvars[v]]['scores_cv']:
                continue
            targdist=acc[k][allvars[v]]['scores_cv'][v].dropna()
            df.append(targdist.mean())
            ds.append(k)
            errors.append(targdist.std())
        df=pandas.DataFrame({'mean':df},index=ds)
        errors=pandas.DataFrame({'mean':errors},index=ds)
        if allvars[v]=='AUROC':
            df.plot.bar(yerr=errors,legend=False,
                    ylim=(0.45,numpy.max(df.values)*1.1),
                        ax=axarr[xy[ctr][0],xy[ctr][1]],
                       title=v)
        else:
            df.plot.bar(yerr=errors,legend=False,
                        ax=axarr[xy[ctr][0],xy[ctr][1]],
                       title=v)
        if xy[ctr][0]==0:
            x_axis = axarr[xy[ctr][0],xy[ctr][1]].axes.get_xaxis()
            x_axis.set_visible(False)
        if xy[ctr][1]==0:
            plt.ylabel(allvars[v]+' +/- SE across CV runs')
        ctr+=1
                                                                  
vars=figurevars        
vars.sort()
#def plot_paper_vars2(vars,pvals,datasets,allvars):
if 1:
    f= plt.figure(figsize=(18,12))
    ax=plt.gca()
    data=None
    errors=None
    for v in vars:
        df=[]
        err=[]
        ds=[]
        for k in datasets:
            if not allvars[v] in acc[k]:
                continue
            if not v in acc[k][allvars[v]]['scores_cv']:
                continue
            targdist=acc[k][allvars[v]]['scores_cv'][v].dropna()
            df.append(targdist.mean())
            ds.append(k)
            err.append(targdist.std())
        if data is None:
            data=pandas.DataFrame({v:df},index=ds)
            errors=pandas.DataFrame({v:err},index=ds)
        else:
            data[v]=pandas.DataFrame({v:df},index=ds)
            errors[v]=pandas.DataFrame({v:err},index=ds)
    data.sort_index(inplace=True)    
    if allvars[v]=='AUROC':
        data.plot.bar(yerr=errors,legend=True,
                ylim=(0.45,numpy.max(df.values)*1.1),
                   title=v,ax=ax,fontsize=20)
    else:
        data.plot.bar(yerr=errors,
                   ax=ax,fontsize=20,ylim=[0,0.3])
    plt.ylabel('R-squared +/- SD across CV runs',fontsize=20)
    plt.legend(fontsize=20,loc=2)  
    plt.tight_layout(1.25)


#plot_paper_vars(figurevars,pvals,datasets,allvars)
plt.savefig('barplots.png',dpi=300)

# %%
data
# Out:
#                              AlcoholHowManyDrinksDay       BMI  \
# attention_network_task       0.001211                 0.002965
# baseline                     0.002484                 0.001352
# baseline_shuffle             0.002784                 0.003009
# big5                         0.027310                 0.025351
# bisbas                       0.023211                 0.002586
# columbia_card_task_hot       0.001323                 0.001395
# discount_titrate             0.001185                 0.003297
# discounting                  0.001409                 0.001361
# dot_pattern_expectancy       0.001039                 0.003084
# drift                        0.001545                 0.004240
# grit                         0.009512                 0.008456
# impulsivity                  0.065136                 0.067185
# intelligence                 0.002893                 0.001270
# kirby                        0.001129                 0.002720
# motor_selective_stop_signal  0.002550                 0.001313
# nondecision                  0.012914                 0.000913
# risktaking                   0.194579                 0.002934
# stop_signal                  0.013439                 0.001108
# stopping                     0.006282                 0.015769
# stroop                       0.001828                 0.007071
# survey                       0.189819                 0.169205
# task                         0.002275                 0.013975
# threebytwo                   0.003597                 0.003313
# thresh                       0.005084                 0.012906
# tower_of_london              0.005190                 0.001930
#
#                              CannabisHowOften  DaysLostLastMonth  \
# attention_network_task       0.005014         NaN
# baseline                     0.002949          0.012756
# baseline_shuffle             0.004356          0.003360
# big5                         0.003974          0.144022
# bisbas                       0.003533          0.150977
# columbia_card_task_hot       0.003227         NaN
# discount_titrate             0.003263         NaN
# discounting                  0.004667          0.005908
# dot_pattern_expectancy       0.004134         NaN
# drift                        0.002536          0.003890
# grit                         0.001718          0.083254
# impulsivity                  0.012327          0.132378
# intelligence                 0.004313          0.004825
# kirby                        0.004306         NaN
# motor_selective_stop_signal  0.002902         NaN
# nondecision                  0.006202          0.008475
# risktaking                   0.029532          0.008585
# stop_signal                  0.003609         NaN
# stopping                     0.002928          0.006021
# stroop                       0.004926         NaN
# survey                       0.039917          0.159708
# task                         0.004381          0.001858
# threebytwo                   0.001848         NaN
# thresh                       0.003004          0.004723
# tower_of_london              0.004397         NaN
#
#                              SmokeEveryDay
# attention_network_task       0.006833
# baseline                     0.006009
# baseline_shuffle             0.002592
# big5                         0.026286
# bisbas                       0.012539
# columbia_card_task_hot       0.008104
# discount_titrate             0.008522
# discounting                  0.011237
# dot_pattern_expectancy       0.001349
# drift                        0.003140
# grit                         0.006960
# impulsivity                  0.010203
# intelligence                 0.003298
# kirby                        0.022863
# motor_selective_stop_signal  0.005854
# nondecision                  0.001233
# risktaking                   0.043250
# stop_signal                  0.001254
# stopping                     0.002390
# stroop                       0.007830
# survey                       0.038422
# task                         0.010059
# threebytwo                   0.001483
# thresh                       0.002942
# tower_of_london              0.007884

# %% [markdown]
# ## Show variables with greater prediction for DDM parameters vs. baseline
#
# ### drift

# %%
k=('drift','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
for v in sigp[k].index:
    plotvars(v,pvals,datasets,allvars)
    print(v)
    print(get_importances(v,k[0],features)  )  
    print('')
# Out:
#                           Measure  Target mean  Null Mean  Effect size  \
# CaffieneOtherSourcesDayMG  r2      0.015254     0.005292   0.009962
#
#                            In-sample  p_unc  p_fdr  \
# CaffieneOtherSourcesDayMG  0.042369   0.0    0.0
#
#                                                                                 top features
# CaffieneOtherSourcesDayMG  [[recent_probes.hddm_drift, directed_forgetting.hddm_drift, Sex]]
# CaffieneOtherSourcesDayMG
#                                 importance       mean
# recent_probes.hddm_drift        0.908333   -13.425610
# directed_forgetting.hddm_drift  0.608333   -4.192041
# Sex                             0.450000   -2.824963

# %% [markdown]
# ### Threshold

# %%
k=('thresh','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
for v in sigp[k].index:
    plotvars(v,pvals,datasets,allvars)
    print(v)
    print(get_importances(v,k[0],features)  )  
    print('')
# Out:
#                                            Measure  Target mean  Null Mean  \
# HowOftenFailedActivitiesDrinking.binarized  AUROC   0.565401     0.472534
# AlcoholHowManyDrinksDay.binarized           AUROC   0.579236     0.524419
# HowOftenUnableRememberDrinking.binarized    AUROC   0.583655     0.540953
# CigsPerDay.binarized                        AUROC   0.579257     0.548350
# BMI                                         r2      0.012906     0.001352
#
#                                             Effect size  In-sample  p_unc  \
# HowOftenFailedActivitiesDrinking.binarized  0.092867    NaN         0.0
# AlcoholHowManyDrinksDay.binarized           0.054817     0.534552   0.0
# HowOftenUnableRememberDrinking.binarized    0.042703     0.506989   0.0
# CigsPerDay.binarized                        0.030908     0.524938   0.0
# BMI                                         0.011555     0.028645   0.0
#
#                                             p_fdr  \
# HowOftenFailedActivitiesDrinking.binarized  0.0
# AlcoholHowManyDrinksDay.binarized           0.0
# HowOftenUnableRememberDrinking.binarized    0.0
# CigsPerDay.binarized                        0.0
# BMI                                         0.0
#
#                                                                                                                                      top features
# HowOftenFailedActivitiesDrinking.binarized  [[adaptive_n_back.hddm_thresh, attention_network_task.hddm_thresh, choice_reaction_time.hddm_thresh]]
# AlcoholHowManyDrinksDay.binarized           [[adaptive_n_back.hddm_thresh, Age, threebytwo.hddm_thresh]]
# HowOftenUnableRememberDrinking.binarized    [[attention_network_task.hddm_thresh, dot_pattern_expectancy.hddm_thresh, recent_probes.hddm_thresh]]
# CigsPerDay.binarized                        [[adaptive_n_back.hddm_thresh, attention_network_task.hddm_thresh, simon.hddm_thresh]]
# BMI                                         [[stim_selective_stop_signal.hddm_thresh.logTr, Age, Sex]]
# HowOftenFailedActivitiesDrinking.binarized
#                                     importance      mean
# adaptive_n_back.hddm_thresh         1.0         0.333080
# attention_network_task.hddm_thresh  1.0        -0.271375
# choice_reaction_time.hddm_thresh    1.0        -0.706958
#
# AlcoholHowManyDrinksDay.binarized
#                              importance      mean
# adaptive_n_back.hddm_thresh  1.000000    0.502821
# Age                          1.000000   -0.236964
# threebytwo.hddm_thresh       0.991667   -0.267626
#
# HowOftenUnableRememberDrinking.binarized
#                                     importance      mean
# attention_network_task.hddm_thresh  1.0        -0.213619
# dot_pattern_expectancy.hddm_thresh  1.0        -0.292034
# recent_probes.hddm_thresh           1.0         0.231322
#
# CigsPerDay.binarized
#                                     importance      mean
# adaptive_n_back.hddm_thresh         1.0         0.311523
# attention_network_task.hddm_thresh  1.0         0.283240
# simon.hddm_thresh                   1.0         0.278461
#
# BMI
#                                               importance      mean
# stim_selective_stop_signal.hddm_thresh.logTr  0.950000   -0.580999
# Age                                           0.358333    0.053035
# Sex                                           0.158333    0.022577

# %% [markdown]
# ### Nondecision time

# %%
k=('nondecision','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
for v in sigp[k].index:
    plotvars(v,pvals,datasets,allvars)
    print(v)
    print(get_importances(v,k[0],features)  )  
    print('')
# Out:
#                                   Measure  Target mean  Null Mean  \
# AlcoholHowManyDrinksDay.binarized  AUROC   0.567682     0.524419
# AlcoholHowManyDrinksDay            r2      0.012914     0.002484
#
#                                    Effect size  In-sample  p_unc  p_fdr  \
# AlcoholHowManyDrinksDay.binarized  0.043264     0.530493   0.0    0.0
# AlcoholHowManyDrinksDay            0.010430     0.064904   0.0    0.0
#
#                                                                                                                    top features
# AlcoholHowManyDrinksDay.binarized  [[simon.hddm_non_decision, threebytwo.hddm_non_decision, adaptive_n_back.hddm_non_decision]]
# AlcoholHowManyDrinksDay            [[simon.hddm_non_decision, threebytwo.hddm_non_decision, Sex]]
# AlcoholHowManyDrinksDay.binarized
#                                    importance      mean
# simon.hddm_non_decision            1.000000   -0.280247
# threebytwo.hddm_non_decision       1.000000    0.386258
# adaptive_n_back.hddm_non_decision  0.991667   -0.248047
#
# AlcoholHowManyDrinksDay
#                               importance      mean
# simon.hddm_non_decision       0.833333   -0.077989
# threebytwo.hddm_non_decision  0.783333    0.054360
# Sex                           0.783333   -0.048559

# %% [markdown]
# ## Show variables with greater prediction for intelligence vs. baseline

# %%
k=('intelligence','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
for v in sigp[k].index:
    plotvars(v,pvals,datasets,allvars)
# Out:
#                                        Measure  Target mean  Null Mean  \
# AlcoholHowOften.binarized               AUROC   0.587700     0.468331
# HighestEducation                        r2      0.103143     0.013093
# HouseholdIncome                         r2      0.048821     0.012531
# HowOftenGuiltRemorseDrinking.binarized  AUROC   0.572284     0.546239
# TrafficAccidentsLifeCount               r2      0.065180     0.052681
# ChildrenNumber                          r2      0.137056     0.127504
#
#                                         Effect size  In-sample  p_unc  p_fdr  \
# AlcoholHowOften.binarized               0.119369    NaN         0.0    0.0
# HighestEducation                        0.090050     0.122951   0.0    0.0
# HouseholdIncome                         0.036290     0.068739   0.0    0.0
# HowOftenGuiltRemorseDrinking.binarized  0.026046    NaN         0.0    0.0
# TrafficAccidentsLifeCount               0.012499     0.087912   0.0    0.0
# ChildrenNumber                          0.009552     0.163549   0.0    0.0
#
#                                                                                                                                               top features
# AlcoholHowOften.binarized               [[cognitive_reflection_survey.correct_proportion, ravens.score, Age]]
# HighestEducation                        [[cognitive_reflection_survey.correct_proportion, Age, ravens.score]]
# HouseholdIncome                         [[cognitive_reflection_survey.correct_proportion, Age, Sex]]
# HowOftenGuiltRemorseDrinking.binarized  [[ravens.score, cognitive_reflection_survey.correct_proportion, Sex]]
# TrafficAccidentsLifeCount               [[ravens.score, Age, cognitive_reflection_survey.correct_proportion]]
# ChildrenNumber                          [[cognitive_reflection_survey.correct_proportion, cognitive_reflection_survey.intuitive_proportion, ravens.score]]

# %% [markdown]
# ## Show variables with greater prediction for stopping vs. baseline

# %%
k=('stopping','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
for v in sigp[k].index:
    plotvars(v,pvals,datasets,allvars)
# Out:
#     Measure  Target mean  Null Mean  Effect size  In-sample  p_unc  p_fdr  \
# BMI  r2      0.015769     0.001352   0.014417     0.052047   0.0    0.0
#
#                                                                                      top features
# BMI  [[stim_selective_stop_signal.hddm_thresh.logTr, stim_selective_stop_signal.hddm_drift, Age]]

# %% [markdown]
# ## Show variables with greater prediction for discounting vs. baseline

# %%
k=('discounting','baseline')
sigp[k]=pvals[k].query('p_fdr <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
imp=get_importance_list(sigp[k],k[0],features)
sigp[k]=sigp[k].join(imp)
display(sigp[k])
#for v in sigp[k].index:
#    plotvars(v,pvals,datasets,allvars)
# Out:
#                           Measure  Target mean  Null Mean  Effect size  \
# Hopeless.binarized         AUROC   0.570405     0.540419   0.029986
# HighestEducation           r2      0.037678     0.013093   0.024585
# CaffienatedSodaCansPerDay  r2      0.025077     0.004000   0.021077
# RetirementAccount          AUROC   0.607340     0.587012   0.020328
#
#                            In-sample  p_unc  p_fdr  \
# Hopeless.binarized         0.602704   0.0    0.0
# HighestEducation           0.064696   0.0    0.0
# CaffienatedSodaCansPerDay  0.050963   0.0    0.0
# RetirementAccount          0.523538   0.0    0.0
#
#                                                                                                            top features
# Hopeless.binarized         [[kirby.hyp_discount_rate_medium.logTr, Age, Sex]]
# HighestEducation           [[bickel_titrator.hyp_discount_rate_medium.logTr, Age, discount_titrate.percent_patient]]
# CaffienatedSodaCansPerDay  [[bickel_titrator.hyp_discount_rate_large.logTr, kirby.hyp_discount_rate_small.logTr, Age]]
# RetirementAccount          [[kirby.hyp_discount_rate_large.logTr, Age, bickel_titrator.hyp_discount_rate_medium.logTr]]

# %% [markdown]
# ### Assess survey variables in terms of their overall predictive utility

# %%
k=('survey','baseline')
df=pandas.DataFrame()
absfeat=pandas.DataFrame()

for v in features['survey']:
    df[v]=features['survey'][v].mean(0)
    absfeat[v]=(features['survey'][v].abs()>0).mean()
    
mean_imp=df.mean(1)
meanabs_survey=pandas.DataFrame({'meanabs':absfeat.mean(1)}).sort_values(by='meanabs',ascending=False)

# %%
df=pandas.DataFrame()
absfeat=pandas.DataFrame()

for v in features['task']:
    df[v]=features['task'][v].mean(0)
    absfeat[v]=(features['task'][v].abs()>0).mean()
    
mean_imp=df.mean(1)
meanabs_task=pandas.DataFrame({'meanabs':absfeat.mean(1)}).sort_values(by='meanabs',ascending=False)

# %% [markdown]
# ## Visualize structure of demographic target variables

# %%
bp=behavpredict.BehavPredict(verbose=True,
     drop_na_thresh=100,
     skip_vars=['RetirementPercentStocks',
     'HowOftenFailedActivitiesDrinking',
     'HowOftenGuiltRemorseDrinking',
     'AlcoholHowOften6Drinks'],
     add_baseline_vars=True,
     freq_threshold=0.1)
bp.load_demog_data()
bp.get_demogdata_vartypes()
# Out:
# replacing bad WeightPounds value for Index(['s028'], dtype='object')
# replacing bad HeightInches value for Index(['s462', 's513', 's517'], dtype='object')
# replacing bad CaffienatedSodaCansPerDay value for Index(['s108'], dtype='object')
# dropping categorical variable: HispanicLatino
# dropping categorical variable: Race
# dropping categorical variable: DiseaseDiagnoses
# dropping categorical variable: DiseaseDiagnosesOther
# dropping categorical variable: MotivationForParticipation
# dropping categorical variable: MotivationOther
# dropping categorical variable: NeurologicalDiagnoses
# dropping categorical variable: NeurologicalDiagnosesDescribe
# dropping categorical variable: OtherDebtSources
# dropping categorical variable: OtherDrugs
# dropping categorical variable: OtherRace
# dropping categorical variable: OtherTobaccoProducts
# dropping categorical variable: PsychDiagnoses
# dropping categorical variable: PsychDiagnosesOther

# %%
demogdata=bp.demogdata.copy()
for i in demogdata.columns:
    if not i in features['task'] and not i in features['survey']:
        del demogdata[i]
        print('removing',i)
demogdata=demogdata.T
demogdata['goodvar']=demogdata.isnull().sum(1)<10
demogdata_clean=demogdata.query('goodvar==True')
print(demogdata.shape)
del demogdata_clean['goodvar']
demogdata_clean=demogdata_clean.T

# these are bad vars that don't have features
dropvars=['HowOftenCantStopDrinking',
'HowOftenFailedActivitiesDrinking',
'HowOftenGuiltRemorseDrinking','AlcoholHowOften6Drinks']

for v in dropvars:
    if v in demogdata_clean:
        del demogdata_clean[v]
        print('removing',v)
from sklearn.linear_model import LinearRegression
from fancyimpute import SimpleFill

def residualize_baseline(df):
    # remove baseline vars
    baseline=df[['Age','Sex']]
    data=df.copy()
    del data['Age']
    del data['Sex']
    #x=SimpleFill().complete(baseline)
    lr=LinearRegression()
    for v in data:
        #print('residualizing',v)
        if data[v].isnull().sum()>0:
            y=SimpleFill().complete(data[v].values[:,numpy.newaxis])
        else:
            y=data[v]
        lr.fit(baseline,y)
        data[v]=y - lr.predict(baseline)
    return data
df_resid=residualize_baseline(demogdata_clean)
# Out:
# removing GamblingProblem
# removing TrafficTicketsLastYearCount
# removing HowOftenDrinkMorning
# removing HowOftenCantStopCannabis
# removing HowOftenFailedActivitiesCannabis
# removing HowOftenDevotedTimeCannabis
# removing HowOftenMemoryConcentrationProblemCannabis
# removing HowOftenHazardousCannabis
# removing CannabisConsideredReduction
# removing AbuseMoreThanOneDrugAtATime
# removing BlackoutFlashbackDrugUse
# removing FeelBadGuiltyDrugUse
# removing SpouseParentsComplainDrugUse
# removing NeglectedFamilyDrugUse
# removing EngagedInIllegalActsToObtainDrugs
# removing WidthdrawalSymptoms
# removing MedicalProblemsDueToDrugUse
# removing DoctorVisitsLastMonth
# (55, 523)
# removing HowOftenCantStopDrinking
# removing HowOftenFailedActivitiesDrinking
# removing HowOftenGuiltRemorseDrinking
# removing AlcoholHowOften6Drinks

# %%
dthresh=2.0
dist=1-numpy.abs(df_resid.corr(method='spearman'))
k=ward(numpy.triu(dist))
c=cut_tree(k,height=dthresh)
ll=leaves_list(k)

matches={}
matchnums={}
clustdict={}
for i in numpy.unique(c):
    matches[i]=[]
    matchnums[i]=[]
    for j in numpy.where(c==i)[0]:
        matches[i].append(df_resid.columns[j])
        clustdict[df_resid.columns[j]]=i
        matchnums[i].append(j)

matchdesc={0:'education/height/weight',1:'relationships',2:'domestic',3:'financial/coffee',
          4:'caffeine',5:'legal problems',6:'smoking',7:'alcohol use',
          8:'alcohol/drug problems',9:'mental health',10:'obesity'}

matches
# Out:
# {0: ['HighestEducation', 'HeightInches', 'WeightPounds'],
#  1: ['RelationshipStatus', 'DivorceCount', 'LongestRelationship'],
#  2: ['RelationshipNumber', 'ChildrenNumber', 'HouseholdIncome'],
#  3: ['RetirementAccount', 'RentOwn', 'CoffeeCupsPerDay'],
#  4: ['TeaCupsPerDay',
#   'CaffienatedSodaCansPerDay',
#   'CaffieneOtherSourcesDayMG'],
#  5: ['TrafficAccidentsLifeCount', 'ArrestedChargedLifeCount'],
#  6: ['LifetimeSmoke100Cigs',
#   'HowLongSmoked',
#   'SmokeEveryDay',
#   'CigsPerDay',
#   'HowSoonSmokeAfterWaking'],
#  7: ['AlcoholHowOften',
#   'AlcoholHowManyDrinksDay',
#   'HowOftenUnableRememberDrinking'],
#  8: ['InjuredDrinking',
#   'RelativeFriendConcernedDrinking',
#   'CannabisPast6Months',
#   'AbleToStopDrugs'],
#  9: ['Nervous',
#   'Hopeless',
#   'RestlessFidgety',
#   'Depressed',
#   'EverythingIsEffort',
#   'Worthless',
#   'Last30DaysUsual'],
#  10: ['BMI', 'Obese']}

# %%
# get top predictive features for each cluster
impdata={}
binarize_features=True
feature_thresh=1e-5
for i in matchdesc.keys():
    print(matchdesc[i])
    print(matches[i])
    df_subset=df_resid

    df_tmp=pandas.DataFrame()
    absfeat_tmp=pandas.DataFrame()

    for v in matches[i]:
        # drop variables that don't have features for both task and survey
        if not v in features['task'] or not v in features['survey']:
            print('ooop',v)
            continue
        minsize=numpy.min([features['survey'][v].shape[0],features['task'][v].shape[0]]).astype('int')
        sfeatures=features['survey'][v].copy()
        sfeatures=sfeatures.iloc[:minsize,:]
        #print(sfeatures.shape)
        tfeatures=features['task'][v].copy()
        tfeatures=tfeatures.iloc[:minsize,:]
        #print(tfeatures.shape)
        all_features=pandas.concat([sfeatures,tfeatures],axis=1) #sfeatures.join(tfeatures)
        if binarize_features:
            all_features[all_features>feature_thresh]=1
            all_features[all_features<-1*feature_thresh]=-1

        del all_features['Sex']
        del all_features['Age']
        df_tmp[v]=all_features.mean(0)
        absfeat_tmp[v]=(all_features.abs()>0).mean(0)

    mean_imp=pandas.DataFrame({'meanimp':df_tmp.mean(1),
                               'meanabs':absfeat_tmp.mean(1)})
    impdata[i]=mean_imp.sort_values(by='meanabs',ascending=False)

 
    display(impdata[i].iloc[:10,:])
# Out:
# education/height/weight
# ['HighestEducation', 'HeightInches', 'WeightPounds']
#                                               meanabs   meanimp
# leisure_time_activity_survey.activity_level  0.663333 -0.003333
# sensation_seeking_survey.disinhibition       0.620000  0.620000
# eating_survey.emotional_eating               0.533333  0.533333
# erq_survey.suppression                       0.506667 -0.013333
# dospert_eb_survey.social                     0.450000  0.210000
# dospert_rt_survey.health_safety              0.443333  0.063333
# bis_bas_survey.BIS                           0.436667 -0.256667
# threebytwo.hddm_drift                        0.416667  0.103333
# time_perspective_survey.present_fatalistic   0.410000 -0.410000
# upps_impulsivity_survey.sensation_seeking    0.406667  0.406667
# relationships
# ['RelationshipStatus', 'DivorceCount', 'LongestRelationship']
#                                                                   meanabs  \
# writing_task.neutral_probability                                 0.630000
# ten_item_personality_survey.agreeableness                        0.530000
# five_facet_mindfulness_survey.observe                            0.483333
# adaptive_n_back.hddm_non_decision                                0.473333
# dospert_rt_survey.financial                                      0.443333
# time_perspective_survey.past_positive                            0.443333
# five_facet_mindfulness_survey.nonjudge                           0.410000
# stroop.hddm_thresh                                               0.393333
# selection_optimization_compensation_survey.loss_based_selection  0.380000
# dospert_rp_survey.financial                                      0.310000
#
#                                                                   meanimp
# writing_task.neutral_probability                                 0.630000
# ten_item_personality_survey.agreeableness                        0.530000
# five_facet_mindfulness_survey.observe                           -0.083333
# adaptive_n_back.hddm_non_decision                                0.470000
# dospert_rt_survey.financial                                     -0.440000
# time_perspective_survey.past_positive                            0.210000
# five_facet_mindfulness_survey.nonjudge                           0.410000
# stroop.hddm_thresh                                               0.393333
# selection_optimization_compensation_survey.loss_based_selection  0.273333
# dospert_rp_survey.financial                                      0.310000
# domestic
# ['RelationshipNumber', 'ChildrenNumber', 'HouseholdIncome']
#                                                                 meanabs  \
# dospert_rt_survey.financial                                    0.656667
# time_perspective_survey.past_positive                          0.646667
# writing_task.neutral_probability                               0.636667
# psychological_refractory_period_two_choices.PRP_slope          0.583333
# dospert_rt_survey.social                                       0.496667
# selection_optimization_compensation_survey.compensation        0.480000
# bis_bas_survey.BAS_drive                                       0.466667
# sensation_seeking_survey.experience_seeking                    0.466667
# five_facet_mindfulness_survey.observe                          0.456667
# selection_optimization_compensation_survey.elective_selection  0.456667
#
#                                                                 meanimp
# dospert_rt_survey.financial                                    0.136667
# time_perspective_survey.past_positive                          0.633333
# writing_task.neutral_probability                               0.636667
# psychological_refractory_period_two_choices.PRP_slope         -0.010000
# dospert_rt_survey.social                                       0.170000
# selection_optimization_compensation_survey.compensation        0.480000
# bis_bas_survey.BAS_drive                                       0.466667
# sensation_seeking_survey.experience_seeking                   -0.466667
# five_facet_mindfulness_survey.observe                         -0.383333
# selection_optimization_compensation_survey.elective_selection -0.456667
# financial/coffee
# ['RetirementAccount', 'RentOwn', 'CoffeeCupsPerDay']
#                                                     meanabs   meanimp
# spatial_span.forward_span                          0.876667 -0.856667
# time_perspective_survey.past_negative              0.736667 -0.570000
# mpq_control_survey.control.ReflogTr                0.713333  0.093333
# dospert_rt_survey.health_safety                    0.706667 -0.626667
# adaptive_n_back.hddm_thresh                        0.680000  0.256667
# eating_survey.cognitive_restraint                  0.666667  0.643333
# information_sampling_task.Fixed_Win_motivation     0.650000 -0.256667
# simon.hddm_non_decision                            0.646667 -0.560000
# sensation_seeking_survey.thrill_adventure_seeking  0.646667  0.033333
# writing_task.neutral_probability                   0.643333  0.643333
# caffeine
# ['TeaCupsPerDay', 'CaffienatedSodaCansPerDay', 'CaffieneOtherSourcesDayMG']
#                                                                   meanabs  \
# leisure_time_activity_survey.activity_level                      0.370000
# eating_survey.cognitive_restraint                                0.330000
# eating_survey.emotional_eating                                   0.303333
# bickel_titrator.hyp_discount_rate_large.logTr                    0.276667
# recent_probes.hddm_drift                                         0.256667
# attention_network_task.alerting_hddm_drift                       0.216667
# writing_task.positive_probability                                0.210000
# selection_optimization_compensation_survey.loss_based_selection  0.186667
# simon.hddm_non_decision                                          0.186667
# bickel_titrator.hyp_discount_rate_medium.logTr                   0.176667
#
#                                                                   meanimp
# leisure_time_activity_survey.activity_level                     -0.266667
# eating_survey.cognitive_restraint                               -0.323333
# eating_survey.emotional_eating                                   0.303333
# bickel_titrator.hyp_discount_rate_large.logTr                    0.260000
# recent_probes.hddm_drift                                        -0.186667
# attention_network_task.alerting_hddm_drift                       0.216667
# writing_task.positive_probability                               -0.210000
# selection_optimization_compensation_survey.loss_based_selection -0.186667
# simon.hddm_non_decision                                          0.186667
# bickel_titrator.hyp_discount_rate_medium.logTr                   0.166667
# legal problems
# ['TrafficAccidentsLifeCount', 'ArrestedChargedLifeCount']
#                                                        meanabs  meanimp
# dospert_rt_survey.health_safety                        0.985    0.985
# theories_of_willpower_survey.endorse_limited_resource  0.535   -0.245
# ten_item_personality_survey.conscientiousness          0.530   -0.530
# dospert_rt_survey.recreational                         0.505    0.505
# information_sampling_task.Fixed_Win_motivation         0.485   -0.485
# eating_survey.uncontrolled_eating                      0.485    0.485
# dospert_rt_survey.social                               0.470    0.470
# time_perspective_survey.present_hedonistic             0.465   -0.465
# ravens.score                                           0.460    0.460
# digit_span.reverse_span                                0.390    0.390
# smoking
# ['LifetimeSmoke100Cigs', 'HowLongSmoked', 'SmokeEveryDay', 'CigsPerDay', 'HowSoonSmokeAfterWaking']
#                                                                  meanabs  \
# sensation_seeking_survey.disinhibition                           0.648
# selection_optimization_compensation_survey.loss_based_selection  0.536
# dospert_eb_survey.ethical                                        0.478
# dospert_eb_survey.social                                         0.428
# dospert_rt_survey.health_safety                                  0.410
# sensation_seeking_survey.experience_seeking                      0.402
# eating_survey.emotional_eating                                   0.398
# ten_item_personality_survey.extraversion                         0.394
# mindful_attention_awareness_survey.mindfulness                   0.382
# dospert_rt_survey.social                                         0.320
#
#                                                                  meanimp
# sensation_seeking_survey.disinhibition                           0.268
# selection_optimization_compensation_survey.loss_based_selection -0.532
# dospert_eb_survey.ethical                                       -0.478
# dospert_eb_survey.social                                         0.428
# dospert_rt_survey.health_safety                                  0.410
# sensation_seeking_survey.experience_seeking                      0.402
# eating_survey.emotional_eating                                  -0.398
# ten_item_personality_survey.extraversion                         0.394
# mindful_attention_awareness_survey.mindfulness                   0.380
# dospert_rt_survey.social                                         0.300
# alcohol use
# ['AlcoholHowOften', 'AlcoholHowManyDrinksDay', 'HowOftenUnableRememberDrinking']
#                                          meanabs   meanimp
# sensation_seeking_survey.disinhibition  1.000000  1.000000
# dospert_rt_survey.health_safety         0.860000  0.860000
# brief_self_control_survey.self_control  0.493333 -0.493333
# simon.hddm_non_decision                 0.410000 -0.356667
# adaptive_n_back.hddm_thresh             0.400000  0.396667
# ten_item_personality_survey.openness    0.336667  0.256667
# eating_survey.cognitive_restraint       0.323333  0.323333
# dospert_rt_survey.financial             0.306667  0.286667
# time_perspective_survey.past_positive   0.306667  0.306667
# dospert_rp_survey.ethical               0.300000 -0.300000
# alcohol/drug problems
# ['InjuredDrinking', 'RelativeFriendConcernedDrinking', 'CannabisPast6Months', 'AbleToStopDrugs']
#                                                meanabs  meanimp
# dospert_rt_survey.health_safety                0.9725   0.5725
# bis11_survey.Motor                             0.9075   0.7375
# sensation_seeking_survey.disinhibition         0.8900   0.8900
# brief_self_control_survey.self_control         0.7800  -0.3350
# sensation_seeking_survey.experience_seeking    0.7625   0.3075
# tower_of_london.planning_time                  0.7200   0.2475
# eating_survey.cognitive_restraint              0.7000   0.1550
# tower_of_london.num_extra_moves                0.6725   0.2575
# simon.hddm_non_decision                        0.6450  -0.1000
# ten_item_personality_survey.conscientiousness  0.6425  -0.1125
# mental health
# ['Nervous', 'Hopeless', 'RestlessFidgety', 'Depressed', 'EverythingIsEffort', 'Worthless', 'Last30DaysUsual']
#                                                          meanabs   meanimp
# time_perspective_survey.past_negative                   0.988571  0.988571
# ten_item_personality_survey.emotional_stability         0.860000 -0.860000
# dospert_eb_survey.social                                0.747143  0.747143
# writing_task.positive_probability                       0.677143 -0.670000
# future_time_perspective_survey.future_time_perspective  0.634286 -0.634286
# dospert_eb_survey.financial                             0.605714  0.605714
# five_facet_mindfulness_survey.nonjudge                  0.572857 -0.572857
# bis_bas_survey.BIS                                      0.557143  0.557143
# time_perspective_survey.past_positive                   0.554286 -0.548571
# erq_survey.suppression                                  0.515714  0.515714
# obesity
# ['BMI', 'Obese']
#                                              meanabs  meanimp
# leisure_time_activity_survey.activity_level  1.000   -1.000
# brief_self_control_survey.self_control       1.000   -1.000
# eating_survey.emotional_eating               1.000    1.000
# erq_survey.suppression                       0.985   -0.985
# bis_bas_survey.BIS                           0.965   -0.965
# dospert_rp_survey.recreational               0.960    0.960
# ten_item_personality_survey.openness         0.955   -0.955
# dietary_decision.health_sensitivity          0.930   -0.930
# eating_survey.uncontrolled_eating            0.895    0.895
# five_facet_mindfulness_survey.observe        0.890   -0.890

# %%
fig=plt.figure(figsize=(14,12))
plt.subplot(1,2,1)
d=dendrogram(k,orientation='left',
             labels=list(df_resid.T.index),
             color_threshold=dthresh,leaf_font_size=12)
plt.plot([dthresh,dthresh],[0,500],'k--')

omult=10
breaks=[]

for i in range(len(d['ivl'])):
    if i>0:
        if clustdict[d['ivl'][i]]==clustdict[d['ivl'][i-1]]:
            continue
    #print(clustdict[d['ivl'][i]],clustdict[d['ivl'][i-1]])
    breaks.append(i)
breaks.append(len(d['ivl']))
replace_sets=[('.',':'),('_',' '),('selection optimization compensation','SOC'),
             ('theories of ','')]

for i in range(1,len(breaks)):
    plt.plot([0,20],[breaks[i]*omult,breaks[i]*omult],'k--',linewidth=0.5)
    if numpy.sum(impdata[clustdict[d['ivl'][breaks[i-1]]]]['meanabs']==1)>2:
        nfeats=numpy.sum(impdata[clustdict[d['ivl'][breaks[i-1]]]]['meanabs']==1).astype('int')
    else:
        nfeats=2
    for j in range(nfeats):
        vartitle=impdata[clustdict[d['ivl'][breaks[i-1]]]].index[j]
        for r in replace_sets:
            vartitle=vartitle.replace(r[0],r[1])
        plt.text(-11.5,0.5*(breaks[i]+breaks[i-1])*omult-j*8+nfeats,
             '%s (%0.2f/%0.2f)'%(vartitle,
                       impdata[clustdict[d['ivl'][breaks[i-1]]]]['meanimp'][j],
                        impdata[clustdict[d['ivl'][breaks[i-1]]]]['meanabs'][j]))
    plt.text(14,0.5*(breaks[i]+breaks[i-1])*omult-4+nfeats,
             matchdesc[clustdict[d['ivl'][breaks[i-1]]]],fontsize=12)

plt.savefig('dendrogram.png',dpi=300,pad_inches=8)

# %% [markdown]
# ## Clustering on predictor loadings

# %% [markdown]
# looks pretty crappy

# %%
surveyfiles=glob.glob('/Users/poldrack/code/Self_Regulation_Ontology/prediction_analyses/R_exports_lasso/features/survey*')
dropvars=['Age','Sex']
loadingdata={'survey':None}
include_task=False

for f in surveyfiles:
    varname=f.split('survey')[1].split('_')[1]
    for d in dropvars:
        if f.find(d)>-1:
            continue
    sdata=pandas.read_csv(f).mean(0)
    if include_task:
        tf=f.replace('features/survey_','features/task_')
        if not os.path.exists(tf):
            print('skipping',varname)
            continue
        tdata=pandas.read_csv(tf).mean(0)
        alldata=pandas.concat((tdata,sdata))
    else:
        alldata=sdata
    if loadingdata['survey'] is None:
        loadingdata['survey']=pandas.DataFrame({varname:alldata})
    else:
        loadingdata['survey'][varname]=alldata
        
loadingdata['survey']=loadingdata['survey'].drop('Age').drop('Sex')
del loadingdata['survey']['Age']
del loadingdata['survey']['Sex']
allvars=[i for i in list(loadingdata['survey'].columns) if not i.find('.binarized')>-1]
for c in allvars:
    if '%s.binarized'%c in loadingdata['survey']:
        del loadingdata['survey']['%s.binarized'%c]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-c6c10b5f0ebe> in <module>()
#      24         loadingdata['survey'][varname]=alldata
#      25
# ---> 26 loadingdata['survey']=loadingdata['survey'].drop('Age').drop('Sex')
#      27 del loadingdata['survey']['Age']
#      28 del loadingdata['survey']['Sex']
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
dist=1-loadingdata['survey'].corr(method='spearman')
k=ward(numpy.triu(dist))
c=cut_tree(k,height=dthresh)
ll=leaves_list(k)

fig=plt.figure(figsize=(14,12))
plt.subplot(1,2,1)
d=dendrogram(k,orientation='left',
             labels=list(loadingdata['survey'].T.index),
             color_threshold=dthresh,leaf_font_size=12)

matches={}
matchnums={}
clustdict={}
for i in numpy.unique(c):
    matches[i]=[]
    matchnums[i]=[]
    for j in numpy.where(c==i)[0]:
        matches[i].append(loadingdata['survey'].columns[j])
        clustdict[loadingdata['survey'].columns[j]]=i
        matchnums[i].append(j)

# %% [markdown]
# ## task-specific prediction analyses - for Aim 2 task selection

# %%
tasks=['attention_network_task', 
       'columbia_card_task_hot', 'discount_titrate', 
       'dot_pattern_expectancy',
       'kirby', 'motor_selective_stop_signal', 'stop_signal', 
       'stroop', 
       'threebytwo', 'tower_of_london']

for t in tasks:
    k=(t,'baseline')
    sigp[k]=pvals[k].query('p_unc <= %f'% pthresh).sort_values(by='Effect size',ascending=False)
    imp=get_importance_list(sigp[k],k[0],features)
    sigp[k]=sigp[k].join(imp)
    display(sigp[k])
    #for v in sigp[k].index:
        #plotvars(v,pvals,datasets,allvars)

# %% [markdown]
# ## Factor analysis on outcome measures
# Exploratory - don't use this

# %%
# %%R -i df_resid -o scores,loadings,varnames
#
#
# dropvars <- names(df_resid) %in% c("HeightInches", "WeightPounds", "CigsPerDay")
# print(dropvars)
# df <- df_resid[,!dropvars]
#
#
# library(psych)
# vss.result=VSS(df,16,fm='mle',plot=FALSE)
# #print(vss.result)
# nfactor=which.min(vss.result$vss.stats$BIC)
# fa.result=fa(df,nfactors=nfactor,fm='mle')
# loadings=fa.result$loadings
# print(fa.result,cut=0.2,sort=TRUE)
# scores=factor.scores(df,fa.result,method='tenBerge')$scores
# #clst=iclust(df_resid)
# Out:
# /usr/local/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Warning message:
#
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: In (function (filename = "Rplot%03d.png", width = 480, height = 480,  :
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:  unable to open connection to X11 display ''
#
#   warnings.warn(x, RRuntimeWarning)
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-62-d4ba2825f847> in <module>()
# ----> 1 get_ipython().run_cell_magic('R', '-i df_resid -o scores,loadings,varnames', '\n\ndropvars <- names(df_resid) %in% c("HeightInches", "WeightPounds", "CigsPerDay") \nprint(dropvars)\ndf <- df_resid[,!dropvars]\n\n\nlibrary(psych)\nvss.result=VSS(df,16,fm=\'mle\',plot=FALSE)\n#print(vss.result)\nnfactor=which.min(vss.result$vss.stats$BIC)\nfa.result=fa(df,nfactors=nfactor,fm=\'mle\')\nloadings=fa.result$loadings\nprint(fa.result,cut=0.2,sort=TRUE)\nscores=factor.scores(df,fa.result,method=\'tenBerge\')$scores\n#clst=iclust(df_resid)')
#
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-129> in R(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.6/site-packages/rpy2/ipython/rmagic.py in R(self, line, cell, local_ns)
#     685                     ro.r.assign(input, val)
#     686
# --> 687         tmpd = self.setup_graphics(args)
#     688
#     689         text_output = ''
#
# /usr/local/lib/python3.6/site-packages/rpy2/ipython/rmagic.py in setup_graphics(self, args)
#     423                 # Note: that %% is to pass into R for interpolation there
#     424                 ro.r.png("%s/Rplots%%03d.png" % tmpd_fix_slashes,
# --> 425                         **argdict)
#     426             elif self.device == 'svg':
#     427                 self.cairo.CairoSVG("%s/Rplot.svg" % tmpd_fix_slashes,
#
# /usr/local/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# /usr/local/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     104         for k, v in kwargs.items():
#     105             new_kwargs[k] = conversion.py2ri(v)
# --> 106         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     107         res = conversion.ri2ro(res)
#     108         return res
#
# RRuntimeError: Error in .External2(C_X11, paste0("png::", filename), g$width, g$height,  :
#   unable to start device PNG

# %%
scores_df=pandas.DataFrame(scores,columns=['smoking severity','mental illness',
                                           'smoking','obesity',
                                           'alcohol','domestic'],index=df_resid.index)
scores_df.to_csv("../Data/Derived_Data/Complete_10-08-2017/factor_scores.csv")
